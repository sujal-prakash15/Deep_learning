# %% [markdown]
# <a href="https://colab.research.google.com/github/sujal-prakash15/Deep_learning/blob/master/word_cloud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import the relevant libraries
import nltk
from nltk import word_tokenize
from nltk.probability import FreqDist
import urllib.request
from matplotlib import pyplot as plt
from wordcloud import WordCloud
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
#Retrieve a copy of the text from the url
text_file = urllib.request.urlopen("https://www.gutenberg.org/cache/epub/64317/pg64317.txt")

#Read and decode the text
text = text_file.read().decode('utf-8')

#Preview a section of the text
print(text[1400:2000])
# Out:
#                             I
#
# In my younger and more vulnerable years my father gave me some advice
# that I’ve been turning over in my mind ever since.
#
# “Whenever you feel like criticizing anyone,” he told me, “just
# remember that all the people in this world haven’t had the advantages
# that you’ve had.”
#
# He didn’t say any more, but we’ve always been unusually communicative
# in a reserved way, and I understood that he meant a great deal more
# than that. In consequence, I’m inclined to reserve all judgements, a
# habit that has opened up many curious natures to me and also made me
# the vi

# %%
#tokenize text by words
words = word_tokenize(text)

#check the number of words
print(f"The total number of words in the text is {len(words)}")
# Out:
# The total number of words in the text is 64006

# %%
#find the frequency of words
fdist = FreqDist(words)

#print the 10 most common words
fdist.most_common(10)
# Out:
# [(',', 3111),
#  ('.', 2471),
#  ('the', 2377),
#  ('and', 1540),
#  ('“', 1457),
#  ('”', 1455),
#  ('a', 1390),
#  ('I', 1377),
#  ('’', 1346),
#  ('of', 1208)]

# %%
#create an empty list to store words
words_no_punc = []

#iterate through the words list to remove punctuations
for word in words:
    if word.isalpha():
        words_no_punc.append(word.lower())

#print number of words without punctuation
print(f"The total number of words without punctuation is {len(words_no_punc)}")
# Out:
# The total number of words without punctuation is 50927

# %%
#find the frequency of words
fdist = FreqDist(words_no_punc)

#Plot the 10 most common words
fdist.plot(10)
plt.show()

# %%
#Download and import list of stopwords
nltk.download("stopwords")
from nltk.corpus import stopwords
#create an empty list to store clean words
clean_words = []
stopwords_list = stopwords.words("english")
#Iterate through the words_no_punc list and add non stopwords to the new clean_words list
for word in words_no_punc:
    if word not in stopwords_list:
        clean_words.append(word)

print(f"The total number of words without punctuation and stopwords is {len(clean_words)}")
# Out:
# The total number of words without punctuation and stopwords is 23783
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#find the frequency of words
fdist = FreqDist(clean_words)

#Plot the 10 most common words
fdist.plot(10)
plt.show()

# %%
#Update the stopwords list
stopwords_list.extend(["said","one","like","came","back"])

#create an empty list to store clean words
clean_words = []

#Iterate through the words_no_punc list and add non stopwords to the new clean_words list
for word in words_no_punc:
    if word not in stopwords_list:
        clean_words.append(word)

# %%
#find the frequency of words
fdist = FreqDist(clean_words)

#Plot the 10 most common words
fdist.plot(10)
plt.show()

# %%
fdist.freq('gatsby')
# Out:
# 0.01105379513633014

# %%
#Convert word list to a single string
clean_words_string = " ".join(clean_words)
print(clean_words_string)
# Out:
# project gutenberg ebook great gatsby scott fitzgerald ebook use anyone anywhere united states parts world cost almost restrictions whatsoever may copy give away terms project gutenberg license included ebook online located united states check laws country located using ebook title great gatsby author scott fitzgerald release date january ebook recently updated january language english produced alex cabal standard ebooks project based transcription produced project gutenberg australia start project gutenberg ebook great gatsby great gatsby scott fitzgerald table contents ii iii iv v vi vii viii ix zelda wear gold hat move bounce high bounce till cry lover lover must thomas parke invilliers younger vulnerable years father gave advice turning mind ever since whenever feel criticizing anyone told remember people world advantages say always unusually communicative reserved way understood meant great deal consequence inclined reserve judgements habit opened many curious natures also made victim veteran bores abnormal mind quick detect attach quality appears normal person college unjustly accused politician privy secret griefs wild unknown men confidences feigned sleep preoccupation hostile levity realized unmistakable sign intimate revelation quivering horizon intimate revelations young men least terms express usually plagiaristic marred obvious suppressions reserving judgements matter infinite hope still little afraid missing something forget father snobbishly suggested snobbishly repeat sense fundamental decencies parcelled unequally birth boasting way tolerance come admission limit conduct may founded hard rock wet marshes certain point care founded east last autumn felt wanted world uniform sort moral attention forever wanted riotous excursions privileged glimpses human heart gatsby man gives name book exempt represented everything unaffected scorn personality unbroken series successful gestures something gorgeous heightened sensitivity promises life related intricate machines register earthquakes ten thousand miles away responsiveness nothing flabby impressionability dignified name creative temperament extraordinary gift hope romantic readiness never found person likely shall ever find turned right end preyed gatsby foul dust floated wake dreams temporarily closed interest abortive sorrows elations men family prominent people middle western city three generations carraways something clan tradition descended dukes buccleuch actual founder line grandfather brother sent substitute civil war started wholesale hardware business father carries today never saw supposed look special reference rather painting hangs father office graduated new quarter century father little later participated delayed teutonic migration known great war enjoyed thoroughly restless instead warm centre world middle west seemed ragged edge decided go east learn bond business everybody knew bond business supposed could support single man aunts uncles talked choosing prep school finally grave hesitant faces father agreed finance year various delays east permanently thought spring practical thing find rooms city warm season left country wide lawns friendly trees young man office suggested take house together commuting town sounded great idea found house cardboard bungalow eighty month last minute firm ordered washington went country alone least days ran old dodge finnish woman made bed cooked breakfast muttered finnish wisdom electric stove lonely day morning man recently arrived stopped road get west egg village asked helplessly told walked lonely longer guide pathfinder original settler casually conferred freedom neighbourhood sunshine great bursts leaves growing trees things grow fast movies familiar conviction life beginning summer much read thing much fine health pulled young air bought dozen volumes banking credit investment securities stood shelf red gold new money mint promising unfold shining secrets midas morgan maecenas knew high intention reading many ...

# %%
#generating the wordcloud
wordcloud = WordCloud(background_color="white").generate(clean_words_string)

#plot the wordcloud
plt.figure(figsize = (15,15))
plt.imshow(wordcloud)

#to remove the axis value
plt.axis("off")
plt.show()

# %%
frq_dict=dict((m,n) for m,n in fdist.items() if len(m)>3)
print(frq_dict)
# Out:
# {'project': 90, 'gutenberg': 32, 'ebook': 13, 'great': 30, 'gatsby': 255, 'scott': 3, 'fitzgerald': 3, 'anyone': 15, 'anywhere': 4, 'united': 15, 'states': 20, 'parts': 3, 'world': 33, 'cost': 4, 'almost': 22, 'restrictions': 2, 'whatsoever': 2, 'copy': 18, 'give': 22, 'away': 69, 'terms': 24, 'license': 17, 'included': 9, 'online': 4, 'located': 7, 'check': 5, 'laws': 11, 'country': 8, 'using': 6, 'title': 1, 'author': 1, 'release': 1, 'date': 4, 'january': 2, 'recently': 2, 'updated': 2, 'language': 1, 'english': 2, 'produced': 5, 'alex': 1, 'cabal': 1, 'standard': 2, 'ebooks': 8, 'based': 3, 'transcription': 2, 'australia': 1, 'start': 10, 'table': 31, 'contents': 1, 'viii': 2, 'zelda': 1, 'wear': 3, 'gold': 7, 'move': 10, 'bounce': 2, 'high': 17, 'till': 7, 'lover': 2, 'must': 42, 'thomas': 2, 'parke': 2, 'invilliers': 1, 'younger': 2, 'vulnerable': 1, 'years': 36,
# %%
data=list((m,n) for m,n in fdist.items() if len(m)>3 and n>50)
print(data)
# Out:
# [('project', 90), ('gatsby', 255), ('away', 69), ('people', 63), ('made', 63), ('little', 103), ('something', 66), ('come', 84), ('never', 63), ('turned', 64), ('right', 51), ('knew', 53), ('could', 62), ('house', 90), ('went', 90), ('going', 70), ('looked', 82), ('long', 63), ('know', 91), ('daisy', 183), ('would', 52), ('door', 65), ('eyes', 86), ('face', 51), ('voice', 58), ('think', 64), ('around', 68), ('hand', 63), ('room', 53), ('moment', 70), ('night', 65), ('well', 53), ('first', 55), ('want', 59), ('time', 76), ('jordan', 71), ('wilson', 77), ('work', 55)]

# %%
import pandas as pd
df=pd.DataFrame(data,columns=['words','freq'])

# %%
df
# Out:
#         words  freq
# 0     project    90
# 1      gatsby   255
# 2        away    69
# 3      people    63
# 4        made    63
# 5      little   103
# 6   something    66
# 7        come    84
# 8       never    63
# 9      turned    64
# 10      right    51
# 11       knew    53
# 12      could    62
# 13      house    90
# 14       went    90
# 15      going    70
# 16     looked    82
# 17       long    63
# 18       know    91
# 19      daisy   183
# 20      would    52
# 21       door    65
# 22       eyes    86
# 23       face    51
# 24      voice    58
# 25      think    64
# 26     around    68
# 27       hand    63
# 28       room    53
# 29     moment    70
# 30      night    65
# 31       well    53
# 32      first    55
# 33       want    59
# 34       time    76
# 35     jordan    71
# 36     wilson    77
# 37       work    55

# %%
import seaborn as sns
sns.catplot(data=df.sort_values(by='freq',axis=0,ascending=False), y="words", x="freq", kind="bar")

# %%
print(clean_words)
# Out:
# ['project', 'gutenberg', 'ebook', 'great', 'gatsby', 'scott', 'fitzgerald', 'ebook', 'use', 'anyone', 'anywhere', 'united', 'states', 'parts', 'world', 'cost', 'almost', 'restrictions', 'whatsoever', 'may', 'copy', 'give', 'away', 'terms', 'project', 'gutenberg', 'license', 'included', 'ebook', 'online', 'located', 'united', 'states', 'check', 'laws', 'country', 'located', 'using', 'ebook', 'title', 'great', 'gatsby', 'author', 'scott', 'fitzgerald', 'release', 'date', 'january', 'ebook', 'recently', 'updated', 'january', 'language', 'english', 'produced', 'alex', 'cabal', 'standard', 'ebooks', 'project', 'based', 'transcription', 'produced', 'project', 'gutenberg', 'australia', 'start', 'project', 'gutenberg', 'ebook', 'great', 'gatsby', 'great', 'gatsby', 'scott', 'fitzgerald', 'table', 'contents', 'ii', 'iii', 'iv', 'v', 'vi', 'vii', 'viii', 'ix', 'zelda', 'wear', 'gold', 'hat', 'move', 'bounce', 'high', 'bounce', 'till', 'cry', 'lover', 'lover', 'must', 'thomas', 'parke', 'invilliers', 'younger', 'vulnerable', 'years', 'father', 'gave', 'advice', 'turning', 'mind', 'ever', 'since', 'whenever', 'feel', 'criticizing', 'anyone', 'told', 'remember', 'people', 'world', 'advantages', 'say', 'always', 'unusually', 'communicative', 'reserved', 'way', 'understood', 'meant', 'great', 'deal', 'consequence', 'inclined', 'reserve', 'judgements', 'habit', 'opened', 'many', 'curious', 'natures', 'also', 'made', 'victim', 'veteran', 'bores', 'abnormal', 'mind', 'quick', 'detect', 'attach', 'quality', 'appears', 'normal', 'person', 'college', 'unjustly', 'accused', 'politician', 'privy', 'secret', 'griefs', 'wild', 'unknown', 'men', 'confidences', 'feigned', 'sleep', 'preoccupation', 'hostile', 'levity', 'realized', 'unmistakable', 'sign', 'intimate', 'revelation', 'quivering', 'horizon', 'intimate', 'revelations', 'young', 'men', 'least', 'terms', 'express', 'usually', 'plagiaristic', 'marred', 'obvious', 'suppressions', 'reserving', 'judgements', 'matter', 'infinite', 'hope', 'still', 'little', 'afraid', 'missing', 'something', 'forget', 'father', 'snobbishly', 'suggested', 'snobbishly', 'repeat', 'sense', 'fundamental', 'decencies', 'parcelled', 'unequally', 'birth', 'boasting', 'way', 'tolerance', 'come', 'admission', 'limit', 'conduct', 'may', 'founded', 'hard', 'rock', 'wet', 'marshes', 'certain', 'point', 'care', 'founded', 'east', 'last', 'autumn', 'felt', 'wanted', 'world', 'uniform', 'sort', 'moral', 'attention', 'forever', 'wanted', 'riotous', 'excursions', 'privileged', 'glimpses', 'human', 'heart', 'gatsby', 'man', 'gives', 'name', 'book', 'exempt', 'represented', 'everything', 'unaffected', 'scorn', 'personality', 'unbroken', 'series', 'successful', 'gestures', 'something', 'gorgeous', 'heightened', 'sensitivity', 'promises', 'life', 'related', 'intricate', 'machines', 'register', 'earthquakes', 'ten', 'thousand', 'miles', 'away', 'responsiveness', 'nothing', 'flabby', 'impressionability', 'dignified', 'name', 'creative', 'temperament', 'extraordinary', 'gift', 'hope', 'romantic', 'readiness', 'never', 'found', 'person', 'likely', 'shall', 'ever', 'find', 'turned', 'right', 'end', 'preyed', 'gatsby', 'foul', 'dust', 'floated', 'wake', 'dreams', 'temporarily', 'closed', 'interest', 'abortive', 'sorrows', 'elations', 'men', 'family', 'prominent', 'people', 'middle', 'western', 'city', 'three', 'generations', 'carraways', 'something', 'clan', 'tradition', 'descended', 'dukes', 'buccleuch', 'actual', 'founder', 'line', 'grandfather', 'brother', 'sent', 'substitute', 'civil', 'war', 'started', 'wholesale', 'hardware', 'business', 'father', 'carries', 'today', 'never', 'saw', 'supposed', 'look', 'special', 'reference', 'rather', 'painting', 'hangs', 'father', 'office', 'graduated', 'new', 'quarter', 'century', 'father', 'little', 'later', 'participated', 'delayed', 'teutonic', 'migration', 'known', 'great', 'war', 'enjoyed', 'thoroughly', 'restless', 'instead', 'warm', 'centre', 'world', 'middle', 'west', 'seemed', 'ragged', 'edge' ...

# %%
from nltk.util import ngrams
trigram=list(ngrams(clean_words,3,pad_right=True,pad_left=True,right_pad_symbol='</s>',left_pad_symbol='</s>'))

# %%
print(trigram[:10])
# Out:
# [('</s>', '</s>', 'project'), ('</s>', 'project', 'gutenberg'), ('project', 'gutenberg', 'ebook'), ('gutenberg', 'ebook', 'great'), ('ebook', 'great', 'gatsby'), ('great', 'gatsby', 'scott'), ('gatsby', 'scott', 'fitzgerald'), ('scott', 'fitzgerald', 'ebook'), ('fitzgerald', 'ebook', 'use'), ('ebook', 'use', 'anyone')]
